# %%
import goodreads_api_client as gr

import src.helper_functions as hf
from bs4 import BeautifulSoup as bs

# %%
client = gr.Client(developer_key='fGkJVZsWA7At7eDPqUec4A')

# %%
isbn_number = '9780553380163'
book = client.Book.show_by_isbn(isbn=isbn_number)
book
# Out:
# OrderedDict([('id', '3869'),
#              ('title', 'A Brief History of Time'),
#              ('isbn', '0553380168'),
#              ('isbn13', '9780553380163'),
#              ('asin', None),
#              ('kindle_asin', None),
#              ('marketplace_id', None),
#              ('country_code', 'RU'),
#              ('image_url',
#               'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1333578746l/3869._SX98_.jpg'),
#              ('small_image_url',
#               'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1333578746l/3869._SX50_.jpg'),
#              ('publication_year', '1998'),
#              ('publication_month', '9'),
#              ('publication_day', '1'),
#              ('publisher', 'Bantam Books'),
#              ('language_code', 'eng'),
#              ('is_ebook', 'false'),
#              ('description',
# ...

# %%
isbn_number = '9780553380163'

link = hf.get_the_link(isbn_number)

pages = hf.get_all_pages(link)
div = hf.div_reviews_all_pages(pages)
  
hf.get_the_rating(div[0])

hf.get_review(div[0])
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# No more reviews
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# /Users/dilkinn/Documents/GALVANIZE/CAPSTONE_3/PopularScienceBookRecommender/notebooks/src/helper_functions.py:80: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 80 of the file /Users/dilkinn/Documents/GALVANIZE/CAPSTONE_3/PopularScienceBookRecommender/notebooks/src/helper_functions.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   soup = bs(r.content, "html")
# ...
